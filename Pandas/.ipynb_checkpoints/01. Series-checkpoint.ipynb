# %% [markdown]
# # Pandas
# 파이썬에서 사용하는 데이터 분석 라이브러리

# %%
import pandas as pd

# %% [markdown]
# # 1. Series
# 1차원 데이터(정수,실수,문자열 등)

# %% [markdown]
# ## Series 객체 생성
# EX) 1월부터 4월까지 평균 온도 데이터(-20, -10, 10, 20)

# %%
temp=pd.Series([-20, -10, 10, 20])

# %%
temp
# Out:
# jan   -20
# feb   -10
# mar    10
# apr    20
# dtype: int64

# %%
temp
# Out:
# 0   -20
# 1   -10
# 2    10
# 3    20
# dtype: int64

# %%
print(temp)
# Out:
# 0   -20
# 1   -10
# 2    10
# 3    20
# dtype: int64

# %%
tmep[0] #1월 온도
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12068/2033130061.py in <module>
# ----> 1 tmep[0] #1월 온도
#
# NameError: name 'tmep' is not defined

# %%
temp[0] #1월 온도
# Out:
# -20

# %%
temp[2] #3월 온도
# Out:
# 10

# %% [markdown]
# # Series 객체 생성(index 지정)

# %%
temp=pd.Series([-20,-10,10,20], index=['jan', 'fab', 'mar', 'apr'])

# %%
temp
# Out:
# jan   -20
# feb   -10
# mar    10
# apr    20
# dtype: int64

# %%
temp['jan']
# Out:
# -20
